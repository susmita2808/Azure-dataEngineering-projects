# %%
# Storage details
storage_account_name = "realtimestorageaccount"
container_name = "data-lake"

# Base path
base_path = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net"

# Bronze paths
bronze_batch_path = f"{base_path}/bronze/batch"
bronze_stream_path = f"{base_path}/bronze/stream"

# Silver paths
silver_batch_path = f"{base_path}/silver/batch"
silver_stream_path = f"{base_path}/silver/stream"

# Dataset-specific paths
bronze_batch_online_retail = f"{bronze_batch_path}/online_retail/online_retail.csv"
silver_batch_online_retail = f"{silver_batch_path}/online_retail/"

bronze_stream_orders = f"{bronze_stream_path}/orders/"
silver_stream_orders = f"{silver_stream_path}/orders/"


gold_batch_path = f"{base_path}/gold/batch"
gold_stream_path = f"{base_path}/gold/stream"

gold_total_revenue = f"{gold_batch_path}/total_revenue/"
gold_revenue_by_country = f"{gold_batch_path}/revenue_by_country/"
gold_top_customers = f"{gold_batch_path}/top_customers/"
gold_daily_sales = f"{gold_batch_path}/daily_sales/"

gold_orders_per_city = f"{gold_stream_path}/orders_per_city/"
gold_revenue_per_city = f"{gold_stream_path}/revenue_per_city/"
gold_realtime_summary = f"{gold_stream_path}/realtime_summary/"
